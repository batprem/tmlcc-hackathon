# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting gemmi==0.4.8
#   Downloading gemmi-0.4.8-cp38-cp38-manylinux2010_x86_64.whl (2.5 MB)
# Requirement already satisfied: pandas==1.2.5 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from -r ./requirements.txt (line 3)) (1.2.5)
# Collecting tqdm==4.62.2
#   Downloading tqdm-4.62.2-py2.py3-none-any.whl (76 kB)
# Collecting catboost
#   Downloading catboost-0.26.1-cp38-none-manylinux1_x86_64.whl (67.4 MB)
# Collecting prefect[viz]
#   Downloading prefect-0.15.6-py3-none-any.whl (568 kB)
# Collecting ase==3.22.0
#   Downloading ase-3.22.0-py3-none-any.whl (2.2 MB)
# Collecting lightgbm==3.2.1
#   Downloading lightgbm-3.2.1-py3-none-manylinux1_x86_64.whl (2.0 MB)
# Collecting xgboost==1.4.2
#   Downloading xgboost-1.4.2-py3-none-manylinux2010_x86_64.whl (166.7 MB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from pandas==1.2.5->-r ./requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from pandas==1.2.5->-r ./requirements.txt (line 3)) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from pandas==1.2.5->-r ./requirements.txt (line 3)) (1.19.5)
# Collecting graphviz
#   Downloading graphviz-0.17-py3-none-any.whl (18 kB)
# Requirement already satisfied: six in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from catboost->-r ./requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: matplotlib in /shared-libs/python3.8/py/lib/python3.8/site-packages (from catboost->-r ./requirements.txt (line 5)) (3.4.3)
# Requirement already satisfied: scipy in /shared-libs/python3.8/py/lib/python3.8/site-packages (from catboost->-r ./requirements.txt (line 5)) (1.7.1)
# Requirement already satisfied: plotly in /shared-libs/python3.8/py/lib/python3.8/site-packages (from catboost->-r ./requirements.txt (line 5)) (5.3.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from lightgbm==3.2.1->-r ./requirements.txt (line 9)) (0.24.2)
# Requirement already satisfied: wheel in /root/venv/lib/python3.8/site-packages (from lightgbm==3.2.1->-r ./requirements.txt (line 9)) (0.37.0)
# Collecting docker>=3.4.1
#   Downloading docker-5.0.2-py2.py3-none-any.whl (145 kB)
# Collecting marshmallow>=3.0.0b19
#   Downloading marshmallow-3.13.0-py2.py3-none-any.whl (47 kB)
# Collecting marshmallow-oneofschema>=2.0.0b2
#   Downloading marshmallow_oneofschema-3.0.1-py2.py3-none-any.whl (5.8 kB)
# Requirement already satisfied: tabulate>=0.8.0 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from prefect[viz]->-r ./requirements.txt (line 7)) (0.8.9)
# Collecting msgpack>=0.6.0
#   Downloading msgpack-1.0.2-cp38-cp38-manylinux1_x86_64.whl (302 kB)
# Requirement already satisfied: pyyaml>=3.13 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from prefect[viz]->-r ./requirements.txt (line 7)) (5.4.1)
# Collecting cloudpickle>=1.3.0
#   Downloading cloudpickle-2.0.0-py3-none-any.whl (25 kB)
# Collecting requests<2.26,>=2.20
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Requirement already satisfied: urllib3>=1.24.3 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from prefect[viz]->-r ./requirements.txt (line 7)) (1.26.7)
# Collecting dask>=2.17.0
#   Downloading dask-2021.9.1-py3-none-any.whl (1.0 MB)
# Collecting pendulum>=2.0.4
#   Downloading pendulum-2.1.2-cp38-cp38-manylinux1_x86_64.whl (155 kB)
# Collecting croniter<2.0,>=0.3.24
#   Downloading croniter-1.0.15-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: mypy-extensions>=0.4.0 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from prefect[viz]->-r ./requirements.txt (line 7)) (0.4.3)
# Collecting distributed>=2.17.0
#   Downloading distributed-2021.9.1-py3-none-any.whl (786 kB)
# Collecting python-box>=5.1.0
#   Downloading python_box-5.4.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: python-slugify>=1.2.6 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from prefect[viz]->-r ./requirements.txt (line 7)) (5.0.2)
# Requirement already satisfied: toml>=0.9.4 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from prefect[viz]->-r ./requirements.txt (line 7)) (0.10.2)
# Collecting click<8.0,>=7.0
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from dask>=2.17.0->prefect[viz]->-r ./requirements.txt (line 7)) (21.0)
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: toolz>=0.8.2 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from dask>=2.17.0->prefect[viz]->-r ./requirements.txt (line 7)) (0.11.1)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2021.9.0-py3-none-any.whl (123 kB)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.8/site-packages (from distributed>=2.17.0->prefect[viz]->-r ./requirements.txt (line 7)) (58.0.4)
# Requirement already satisfied: tornado>=6.0.3 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from distributed>=2.17.0->prefect[viz]->-r ./requirements.txt (line 7)) (6.1)
# Collecting tblib>=1.6.0
#   Downloading tblib-1.7.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: jinja2 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from distributed>=2.17.0->prefect[viz]->-r ./requirements.txt (line 7)) (3.0.1)
# Collecting zict>=0.1.3
#   Downloading zict-2.0.0-py3-none-any.whl (10 kB)
# Collecting psutil>=5.0
#   Downloading psutil-5.8.0-cp38-cp38-manylinux2010_x86_64.whl (296 kB)
# Collecting sortedcontainers!=2.0.0,!=2.0.1
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from matplotlib->catboost->-r ./requirements.txt (line 5)) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from matplotlib->catboost->-r ./requirements.txt (line 5)) (8.3.2)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from matplotlib->catboost->-r ./requirements.txt (line 5)) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from matplotlib->catboost->-r ./requirements.txt (line 5)) (1.3.2)
# Collecting locket
#   Downloading locket-0.2.1-py2.py3-none-any.whl (4.1 kB)
# Collecting pytzdata>=2020.1
#   Downloading pytzdata-2020.1-py2.py3-none-any.whl (489 kB)
# Requirement already satisfied: text-unidecode>=1.3 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from python-slugify>=1.2.6->prefect[viz]->-r ./requirements.txt (line 7)) (1.3)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from requests<2.26,>=2.20->prefect[viz]->-r ./requirements.txt (line 7)) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from requests<2.26,>=2.20->prefect[viz]->-r ./requirements.txt (line 7)) (4.0.0)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from scikit-learn!=0.22.0->lightgbm==3.2.1->-r ./requirements.txt (line 9)) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from scikit-learn!=0.22.0->lightgbm==3.2.1->-r ./requirements.txt (line 9)) (1.0.1)
# Collecting heapdict
#   Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from jinja2->distributed>=2.17.0->prefect[viz]->-r ./requirements.txt (line 7)) (2.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from plotly->catboost->-r ./requirements.txt (line 5)) (8.0.1)
# Installing collected packages: locket, partd, idna, heapdict, fsspec, cloudpickle, zict, websocket-client, tblib, sortedcontainers, requests, pytzdata, psutil, msgpack, marshmallow, dask, click, python-box, pendulum, marshmallow-oneofschema, docker, distributed, croniter, prefect, graphviz, xgboost, tqdm, lightgbm, gemmi, catboost, ase
#   Attempting uninstall: idna
#     Found existing installation: idna 3.2
#     Not uninstalling idna at /shared-libs/python3.8/py-core/lib/python3.8/site-packages, outside environment /root/venv
#     Can't uninstall 'idna'. No files were found to uninstall.
#   Attempting uninstall: requests
#     Found existing installation: requests 2.26.0
#     Not uninstalling requests at /shared-libs/python3.8/py/lib/python3.8/site-packages, outside environment /root/venv
#     Can't uninstall 'requests'. No files were found to uninstall.
#   Attempting uninstall: click
#     Found existing installation: click 8.0.1
#     Not uninstalling click at /shared-libs/python3.8/py/lib/python3.8/site-packages, outside environment /root/venv
#     Can't uninstall 'click'. No files were found to uninstall.
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.62.3
#     Not uninstalling tqdm at /shared-libs/python3.8/py/lib/python3.8/site-packages, outside environment /root/venv
#     Can't uninstall 'tqdm'. No files were found to uninstall.
# Successfully installed ase-3.22.0 catboost-0.26.1 click-7.1.2 cloudpickle-2.0.0 croniter-1.0.15 dask-2021.9.1 distributed-2021.9.1 docker-5.0.2 fsspec-2021.9.0 gemmi-0.4.8 graphviz-0.17 heapdict-1.0.1 idna-2.10 lightgbm-3.2.1 locket-0.2.1 marshmallow-3.13.0 marshmallow-oneofschema-3.0.1 msgpack-1.0.2 partd-1.2.0 pendulum-2.1.2 prefect-0.15.6 psutil-5.8.0 python-box-5.4.1 pytzdata-2020.1 requests-2.25.1 sortedcontainers-2.4.0 tblib-1.7.0 tqdm-4.62.2 websocket-client-1.2.1 xgboost-1.4.2 zict-2.0.0

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cf8541de-dbc3-45f6-bc1e-4fa446cacbcd' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
